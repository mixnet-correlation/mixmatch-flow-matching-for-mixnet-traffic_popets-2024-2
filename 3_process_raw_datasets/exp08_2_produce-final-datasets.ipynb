# %% [markdown]
# ## Produce Datasets in Our Format, DeepCoFFEA Format, and MixCorr Format from Raw `exp08` Dataset

# %%
from glob import glob
from os import makedirs
from shutil import rmtree
from datetime import datetime
from os.path import join

from lib_analyze_exps import parse_run, create_mixcorr_dataset

# %%
# We expect Notebook 'exp08_1_check-raw-dataset.ipynb' to have run _before_ this Notebook is run.
# Large files are reassembled from their `split`s before in Notebook 'exp08_1_check-raw-dataset.ipynb',
# and this Notebook expects the large unified files to be present.

# %%
### MODIFY BEGIN ###

# Specify the name of the experiment that is supposed to be processed from raw.
EXP_NAME = "exp08_nym-binaries-v1.1.13_static-http-download"

# Specify parent directory of raw experimental results directory.
RAW_EXP_DIR_PARENT = "/PRIVATE_PATH/"

###  MODIFY END  ###

# %%
# Construct paths to:
#   * RAW_EXP_DIR => raw experimental result files repository,
#   * PROC_EXP_DIR_OUR => processed version of the dataset in our flowpair format after running this notebook,
#   * PROC_EXP_DIR_DCOFFEA => processed version of the dataset in DeepCoFFEA flowpair format after running this notebook,
#   * PROC_EXP_DIR_MIXCORR => processed version of the dataset in MixCorr flowpair format after running this notebook.
#
# CAUTION: The filesystem locations PROC_EXP_DIR_* will be deleted if they already exist.
RAW_EXP_DIR = join(RAW_EXP_DIR_PARENT, f"dataset_{EXP_NAME}_raw")
PROC_EXP_DIR_OUR = join(RAW_EXP_DIR_PARENT, f"dataset_{EXP_NAME}_filtered-to-start-end")
PROC_EXP_DIR_DCOFFEA = join(RAW_EXP_DIR_PARENT, f"dataset_{EXP_NAME}_format-deepcoffea_filtered-to-start-end")
PROC_EXP_DIR_MIXCORR = join(RAW_EXP_DIR_PARENT, f"dataset_{EXP_NAME}_format-mixcorr_filtered-to-start-end")

# %%
# Delete and recreate the final dataset directories.

rmtree(PROC_EXP_DIR_OUR, ignore_errors = True)
rmtree(PROC_EXP_DIR_DCOFFEA, ignore_errors = True)
rmtree(PROC_EXP_DIR_MIXCORR, ignore_errors = True)

makedirs(PROC_EXP_DIR_OUR, mode=0o755)
makedirs(PROC_EXP_DIR_DCOFFEA, mode=0o755)
makedirs(PROC_EXP_DIR_MIXCORR, mode=0o755)

# %%
# Discover all succeeded runs to process.
runs_succeeded = sorted(glob(join(RAW_EXP_DIR, "*", "exp08_curl_run_*", "SUCCEEDED")))

# For exp08, this should give: 35,611.
print(f"{len(runs_succeeded):,}")
# Out:
# 35,611

# %%
print(f"----- [{datetime.now().strftime('%Y-%m-%d_%H:%M:%S.%f')}] Beginning to process raw exp08 dataset -----\n")

run_ctr = 1

for run_succeeded in runs_succeeded:
    
    parse_run(
        PROC_EXP_DIR_OUR,
        PROC_EXP_DIR_DCOFFEA,
        run_ctr,
        run_succeeded)
    
    run_ctr += 1

print(f"----- [{datetime.now().strftime('%Y-%m-%d_%H:%M:%S.%f')}] Finished processing raw exp08 dataset -----")
# Out:
# ----- [2023-04-24_16:37:40.372685] Beginning to process raw exp08 dataset -----
#
# [0250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00250...
#
# [0500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00500...
#
# [0750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00750...
#
# [1000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01000...
#
# [1250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01250...
#
# [1500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01500...
#
# [1750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01750...
#
# [2000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02000...
#
# [2250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02250...
#
# [2500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02500...
#
# [2750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02750...
#
# [3000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03000...
#
# [3250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03250...
#
# [3500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03500...
#
# [3750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03750...
#
# [4000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04000...
#
# [4250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04250...
#
# [4500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04500...
#
# [4750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04750...
#
# [5000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05000...
#
# [5250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05250...
#
# [5500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05500...
#
# [5750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05750...
#
# [6000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06000...
#
# [6250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06250...
#
# [6500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-23-39_mixcorr-nym-endpoints-ccx22-exp08-one_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06500...
#
# [6750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00027...
#
# [7000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00277...
#
# [7250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00527...
#
# [7500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00777...
#
# [7750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01027...
#
# [8000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01277...
#
# [8250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01527...
#
# [8500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01777...
#
# [8750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02027...
#
# [9000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02277...
#
# [9250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02527...
#
# [9500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02777...
#
# [9750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03027...
#
# [10000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03277...
#
# [10250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03527...
#
# [10500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03777...
#
# [10750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04027...
#
# [11000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04277...
#
# [11250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04527...
#
# [11500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04777...
#
# [11750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05027...
#
# [12000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05277...
#
# [12250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05527...
#
# [12500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05777...
#
# [12750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06027...
#
# [13000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06277...
#
# [13250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06527...
#
# [13500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06777...
#
# [13750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-24_mixcorr-nym-endpoints-ccx22-exp08-two_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_07027...
#
# [14000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00119...
#
# [14250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00369...
#
# [14500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00619...
#
# [14750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00869...
#
# [15000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01119...
#
# [15250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01369...
#
# [15500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01619...
#
# [15750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01869...
#
# [16000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02119...
#
# [16250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02369...
#
# [16500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02619...
#
# [16750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02869...
#
# [17000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03119...
#
# [17250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03369...
#
# [17500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03619...
#
# [17750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03869...
#
# [18000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04119...
#
# [18250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04369...
#
# [18500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04619...
#
# [18750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04869...
#
# [19000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05119...
#
# [19250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05369...
#
# [19500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05619...
#
# [19750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05869...
#
# [20000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06119...
#
# [20250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06369...
#
# [20500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-24-43_mixcorr-nym-endpoints-ccx22-exp08-three_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06619...
#
# [20750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00004...
#
# [21000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00254...
#
# [21250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00504...
#
# [21500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00754...
#
# [21750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01004...
#
# [22000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01254...
#
# [22250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01504...
#
# [22500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01754...
#
# [22750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02004...
#
# [23000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02254...
#
# [23250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02504...
#
# [23500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02754...
#
# [23750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03004...
#
# [24000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03254...
#
# [24250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03504...
#
# [24500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03754...
#
# [24750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04004...
#
# [25000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04254...
#
# [25250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04504...
#
# [25500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04754...
#
# [25750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05004...
#
# [26000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05254...
#
# [26250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05504...
#
# [26500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05754...
#
# [26750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06004...
#
# [27000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06254...
#
# [27250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06504...
#
# [27500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06754...
#
# [27750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_07004...
#
# [28000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_07254...
#
# [28250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_07504...
#
# [28500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_07754...
#
# [28750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-03_mixcorr-nym-endpoints-ccx22-exp08-four_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_08004...
#
# [29000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00108...
#
# [29250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00358...
#
# [29500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00608...
#
# [29750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_00858...
#
# [30000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01108...
#
# [30250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01358...
#
# [30500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01608...
#
# [30750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_01858...
#
# [31000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02108...
#
# [31250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02358...
#
# [31500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02608...
#
# [31750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_02858...
#
# [32000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03108...
#
# [32250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03358...
#
# [32500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03608...
#
# [32750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_03858...
#
# [33000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04108...
#
# [33250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04358...
#
# [33500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04608...
#
# [33750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_04858...
#
# [34000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05108...
#
# [34250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05358...
#
# [34500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05608...
#
# [34750] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_05858...
#
# [35000] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06108...
#
# [35250] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06358...
#
# [35500] Processing /PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_raw/2023-04-14_16-25-31_mixcorr-nym-endpoints-ccx22-exp08-five_exp08_nym-binaries-v1.1.13_static-http-download/exp08_curl_run_06608...
#
# ----- [2023-04-25_06:40:33.455724] Finished processing raw exp08 dataset -----

# %%
# In-between this and the above cell, Jupyter Notebook 'dataset-subsets_train-val-test.ipynb'
# needs to have been run on the newly produced dataset above.

# Thus, include this cell in order to reset the environment for production of the
# MixCorr-formatted version of this dataset.

# Make sure to run cells 1, 2, and 3 at the top first, before returning to this cell, running
# it, and continuing downwards from here.

rmtree(PROC_EXP_DIR_MIXCORR, ignore_errors = True)
makedirs(PROC_EXP_DIR_MIXCORR, mode=0o755)

# %%
print(f"----- [{datetime.now().strftime('%Y-%m-%d_%H:%M:%S.%f')}] Beginning to produce MixCorr-formatted dataset for exp08 -----\n")

# Create dataset in MixCorr format based on existing dataset in our format.
create_mixcorr_dataset(PROC_EXP_DIR_OUR, PROC_EXP_DIR_MIXCORR)

print(f"----- [{datetime.now().strftime('%Y-%m-%d_%H:%M:%S.%f')}] Finished producing MixCorr-formatted dataset for exp08 -----")
# Out:
# ----- [2023-04-25_10:11:24.873769] Beginning to produce MixCorr-formatted dataset for exp08 -----
#
# Considering flowpairs of dataset split 'train' now...
# Done with flowpairs of dataset split 'train'
#
# Considering flowpairs of dataset split 'val' now...
# Done with flowpairs of dataset split 'val'
#
# Considering flowpairs of dataset split 'test' now...
# Done with flowpairs of dataset split 'test'
#
# ----- [2023-04-25_10:23:10.900708] Finished producing MixCorr-formatted dataset for exp08 -----

# %%
# Split files in newly produced MixCorr-formatted dataset of at least 95 MiB into
# multiple files in order to be able to upload to GitHub.

files_too_large = ! find {PROC_EXP_DIR_MIXCORR} -type f -size +95M

for file_too_large in files_too_large:
    
    ! split --verbose --lines=5000 --numeric-suffixes=01 {file_too_large} {file_too_large}.
    ! cat {file_too_large}.?? > {PROC_EXP_DIR_MIXCORR}/tmp_file_too_large
    ! cmp --verbose --print-bytes {PROC_EXP_DIR_MIXCORR}/tmp_file_too_large {file_too_large}
    ! rm {file_too_large} {PROC_EXP_DIR_MIXCORR}/tmp_file_too_large
# Out:
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_from_gateway_data.01'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_from_gateway_data.02'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_from_gateway_data.03'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_from_gateway_data.04'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_from_gateway_data.05'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_responder_to_gateway_data.01'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_responder_to_gateway_data.02'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_responder_to_gateway_data.03'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_responder_to_gateway_data.04'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_responder_to_gateway_data.05'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_responder_from_gateway_ack.01'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_responder_from_gateway_ack.02'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_responder_from_gateway_ack.03'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_responder_from_gateway_ack.04'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_responder_from_gateway_ack.05'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_from_gateway_ack.01'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_from_gateway_ack.02'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_from_gateway_ack.03'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_from_gateway_ack.04'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_from_gateway_ack.05'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_to_gateway_data.01'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_to_gateway_data.02'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_to_gateway_data.03'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_to_gateway_data.04'
# creating file '/PRIVATE_PATH/dataset_exp08_nym-binaries-v1.1.13_static-http-download_format-mixcorr_filtered-to-start-end/train_initiator_to_gateway_data.05'
